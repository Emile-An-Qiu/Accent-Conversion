# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/drive/MyDrive/Github2
# %cd /content/drive/MyDrive/Github2
# Out:
# /content/drive/MyDrive/Github2

# %%
# !wget https://github.com/Emile-An-Qiu/Accent-Conversion/archive/refs/heads/main.zip -O Accent-Conversion.zip

# !unzip Accent-Conversion.zip

# !mv Accent-Conversion-main Accent-Conversion

# !rm Accent-Conversion.zip
# Out:
# --2026-04-08 23:30:59--  https://github.com/Emile-An-Qiu/Accent-Conversion/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/Emile-An-Qiu/Accent-Conversion/zip/refs/heads/main [following]
# --2026-04-08 23:30:59--  https://codeload.github.com/Emile-An-Qiu/Accent-Conversion/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.27.177.114
# Connecting to codeload.github.com (codeload.github.com)|20.27.177.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘Accent-Conversion.zip’
#
# Accent-Conversion.z     [      <=>           ] 120.81M  10.3MB/s    in 16s
#
# 2026-04-08 23:31:15 (7.68 MB/s) - ‘Accent-Conversion.zip’ saved [126679639]
#
# Archive:  Accent-Conversion.zip
# ...
